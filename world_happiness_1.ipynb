# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.shape
# Out:
# (158, 12)

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
data.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
print(data['Region'].value_counts(dropna=False))
#That means; there are 40 Sab-Saharan Africa, 29 Central and Eastern Europe etc. countries in this report
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
pd.DataFrame(dict(data['Region'].value_counts()).items(),columns=['Region','Numbers'])
# Out:
#                             Region  Numbers
# 0               Sub-Saharan Africa       40
# 1       Central and Eastern Europe       29
# 2      Latin America and Caribbean       22
# 3                   Western Europe       21
# 4  Middle East and Northern Africa       20
# 5                Southeastern Asia        9
# 6                    Southern Asia        7
# 7                     Eastern Asia        6
# 8                    North America        2
# 9        Australia and New Zealand        2

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data=data.drop(['Standard Error'], axis=1)# we are dropping this column cause data is unnecessary

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, fmt='0.2f', linewidths=0.5)
plt.show()

# %% [markdown]
# This is a correlation table for the features of world happiness. We can see that Happiness Rank and Happiness Score are inversely proportional, lower the Happiness Rank, higher will be the Happiness Score, and higher the other seven factors. So let's remove the Happiness Rank and see the correlation of features again.

# %%
df=data.drop(['Happiness Rank'], axis =1)

# %%
corr=df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True,linewidths=0.5,fmt='0.2f')
plt.show()

# %%
pd.plotting.scatter_matrix(data,figsize=(20,15),diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05)
plt.yticks(rotation=90)

plt.show()

# %%
data.skew(axis=0,skipna=True)
# Out:
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#visualization

plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Happiness Score',data = data)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# North America, Australia and New Zealand have the most Happiness Score, hence they were the most happy region and Sub- Saharan Africa the least happy region

# %%
plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Health (Life Expectancy)',data = data)
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'Region', y = 'Dystopia Residual', data = data, palette = 'vlag')
plt.xticks(rotation = 90)
plt.title('Dystopia Level in year 2015', fontsize = 20)
plt.show()

# %% [markdown]
# Dystopia Level is still most in Latin America and Carribean, regardless of this score this region has good Happiness Score level but an average Life Expectancy Level

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
plt.figure(figsize = (9,4))
sns.kdeplot(data['Happiness Score'])
plt.title('Happiness Score of the World', fontsize = 13)

plt.show()

# %%
plt.figure(figsize=(9,4))
sns.kdeplot(data['Health (Life Expectancy)'])
plt.title("Health Over the year")
plt.show()

# %%
plt.figure(figsize=(9,4))
sns.kdeplot(data['Economy (GDP per Capita)'])
plt.title("Economy for the year")
plt.show()

# %%
plt.figure(figsize=(9,4))
sns.kdeplot(data['Family'])

plt.title("Family for the year")
plt.show()

# %%
plt.plot(data['Happiness Score'], data['Health (Life Expectancy)'])
plt.xlabel=('Happiness Score')
plt.ylabel=('Life Expectancy')
plt.title('Life Expectancy vs Happiness score', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Life Expectancy vs Happiness score')

# %%
data.head(4)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# ...

# %% [markdown]
# We will drop Country Region and Happiness rank from the model since these features are not important in model building

# %%
data=data.drop(['Country','Region','Happiness Rank'], axis=1)

# %%
data.head(2)
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
data.columns
# Out:
# Index(['Happiness Score', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
X= data[['Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]
y=data['Happiness Score']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
lr=LinearRegression()

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,random_state=40,test_size=0.3)
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.9999999322647383

# %%
y_pred=lr.predict(X_test)

# %%
print(y_pred)
# Out:
# [6.29476124 4.88451944 4.43562777 7.4060111  3.66727007 5.85520032
#  4.95935248 5.75439452 6.32890883 5.07328012 4.21851475 6.16766698
#  4.50725656 6.57503487 5.98371795 6.7977146  5.19231419 3.81918652
#  7.22566696 5.84763269 3.93086548 4.86722105 4.83920636 4.79960604
#  3.68091525 5.33250169 4.41931658 4.68553567 4.73859658 5.05728245
#  3.89652799 6.93732218 4.78644571 7.18726215 6.94019384 5.54819258
#  4.1942931  7.28395759 6.12275763 4.56465131 6.6696461  4.3069585
#  7.52700197 4.03308179 7.37806487 4.0767724  5.70885362 5.95967392]

# %%
print(y_test)
# Out:
# 38     6.295
# 97     4.885
# 123    4.436
# 5      7.406
# 148    3.667
# 53     5.855
# 94     4.959
# 62     5.754
# 35     6.329
# 89     5.073
# 133    4.218
# 40     6.168
# 122    4.507
# 28     6.575
# 46     5.984
# 23     6.798
# 81     5.192
# 144    3.819
# 11     7.226
# 54     5.848
# 140    3.931
# 100    4.867
# 102    4.839
# 103    4.800
# 146    3.681
# 75     5.332
# 124    4.419
# 109    4.686
# 106    4.739
# 90     5.057
# 142    3.896
# 18     6.937
# 105    4.786
# 13     7.187
# 17     6.940
# 69     5.548
# 134    4.194
# 9      7.284
# 42     6.123
# 116    4.565
# 26     6.670
# 128    4.307
# 2      7.527
# 136    4.033
# 6      7.378
# 135    4.077
# 64     5.709
# 48     5.960
# Name: Happiness Score, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(y_test,y_pred)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_forest = RandomForestRegressor(n_estimators = 8, random_state = 42)
regressor_forest.fit(X_train, y_train)
regressor_forest.score(X_test,y_test)
# Out:
# 0.9192092850260998
